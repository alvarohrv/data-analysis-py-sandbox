# %%
# Validación simple de librerías (import + __version__) [web:54]

try:
    import numpy as np
    print("✅ numpy instalado!")
    print("Versión:", np.__version__)
except Exception as e:
    print("❌ numpy NO disponible:", e)

try:
    import pandas as pd
    print("\n✅ pandas instalado!")
    print("Versión:", pd.__version__)  # ejemplo típico [web:53]
except Exception as e:
    print("\n❌ pandas NO disponible:", e)

try:
    import scipy
    print("\n✅ scipy instalado!")
    print("Versión:", scipy.__version__)
except Exception as e:
    print("\n❌ scipy NO disponible:", e)

try:
    import sklearn
    print("\n✅ scikit-learn (sklearn) instalado!")
    print("Versión:", sklearn.__version__)
except Exception as e:
    print("\n❌ scikit-learn (sklearn) NO disponible:", e)

try:
    import matplotlib
    print("\n✅ matplotlib instalado!")
    print("Versión:", matplotlib.__version__)
except Exception as e:
    print("\n❌ matplotlib NO disponible:", e)

try:
    import seaborn as sns
    print("\n✅ seaborn instalado!")
    print("Versión:", sns.__version__)
except Exception as e:
    print("\n❌ seaborn NO disponible:", e)

try:
    import statsmodels
    print("\n✅ statsmodels instalado!")
    print("Versión:", statsmodels.__version__)
except Exception as e:
    print("\n❌ statsmodels NO disponible:", e)

try:
    import janitor  # pip: pyjanitor / import: janitor
    print("\n✅ pyjanitor (janitor) instalado!")
    print("Versión:", janitor.__version__)
except Exception as e:
    print("\n❌ pyjanitor (janitor) NO disponible:", e)

try:
    import palmerpenguins
    print("\n✅ palmerpenguins instalado!")
    print("Versión:", palmerpenguins.__version__)
except Exception as e:
    print("\n❌ palmerpenguins NO disponible:", e)

try:
    import empiricaldist
    print("\n✅ empiricaldist instalado!")
    print("Versión:", empiricaldist.__version__)
except Exception as e:
    print("\n❌ empiricaldist NO disponible:", e)

try:
    import session_info
    print("\n✅ session_info instalado!")
    print("Versión:", session_info.__version__)
except Exception as e:
    print("\n❌ session_info NO disponible:", e)
# Out:
# ✅ numpy instalado!
# Versión: 2.4.0
#
# ✅ pandas instalado!
# Versión: 2.3.3
#
# ✅ scipy instalado!
# Versión: 1.16.3
#
# ✅ scikit-learn (sklearn) instalado!
# Versión: 1.8.0
#
# ✅ matplotlib instalado!
# Versión: 3.10.8
#
# ✅ seaborn instalado!
# Versión: 0.13.2
#
# ✅ statsmodels instalado!
# Versión: 0.14.6
#
# ✅ pyjanitor (janitor) instalado!
# Versión: 0.32.7
#
# ✅ palmerpenguins instalado!
# Versión: 0.1.4
#
# ✅ empiricaldist instalado!
#
# ❌ empiricaldist NO disponible: module 'empiricaldist' has no attribute '__version__'
#
# ✅ session_info instalado!
# Versión: v1.0.1
# /usr/local/lib/python3.12/site-packages/palmerpenguins/penguins.py:2: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
